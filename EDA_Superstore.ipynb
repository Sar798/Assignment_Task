# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Datasets

# %%
df = pd.read_excel(r"C:\Users\m\Downloads\Sample_-_Superstore.xls",sheet_name = 0)
df1 = pd.read_excel(r"C:\Users\m\Downloads\Sample_-_Superstore.xls",sheet_name = 1)
df2 = pd.read_excel(r"C:\Users\m\Downloads\Sample_-_Superstore.xls",sheet_name = 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Dropping the columns

# %%
df.drop(["Row ID","Customer ID","Postal Code"],axis = 1,inplace = True)

# %%
df.shape
# Out:
# (9994, 18)

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9994                           9994
# mean   2016-04-30 00:07:12.259355648  2016-05-03 23:06:58.571142912
# min              2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%              2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%              2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%              2017-05-14 00:00:00            2017-05-18 00:00:00
# max              2017-12-30 00:00:00            2018-01-05 00:00:00
# std                              NaN                            NaN
#
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# ...

# %% [markdown]
# ### Duplicates

# %%
df[df.duplicated()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode   Customer Name  \
# 3406  US-2014-150119 2014-04-23 2014-04-27  Standard Class  Laurel Beltran
#
#           Segment        Country      City State Region       Product ID  \
# 3406  Home Office  United States  Columbus  Ohio   East  FUR-CH-10002965
#
#        Category Sub-Category  \
# 3406  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ### Type Casting

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df["Quantity"] = df["Quantity"].astype("int8")

# %% [markdown]
# ### Structural Errors

# %%
for i in df.columns:
    print(i,df[i].unique())
    print()    # There are no Structural errors
# Out:
# Order ID ['CA-2016-152156' 'CA-2016-138688' 'US-2015-108966' ... 'CA-2014-110422'
#  'CA-2017-121258' 'CA-2017-119914']
#
# Order Date <DatetimeArray>
# ['2016-11-08 00:00:00', '2016-06-12 00:00:00', '2015-10-11 00:00:00',
#  '2014-06-09 00:00:00', '2017-04-15 00:00:00', '2016-12-05 00:00:00',
#  '2015-11-22 00:00:00', '2014-11-11 00:00:00', '2014-05-13 00:00:00',
#  '2014-08-27 00:00:00',
#  ...
#  '2016-10-11 00:00:00', '2014-06-18 00:00:00', '2017-02-28 00:00:00',
#  '2015-05-09 00:00:00', '2014-11-06 00:00:00', '2015-12-29 00:00:00',
#  '2014-04-03 00:00:00', '2016-06-03 00:00:00', '2015-04-12 00:00:00',
#  '2014-01-21 00:00:00']
# Length: 1237, dtype: datetime64[ns]
#
# Ship Date <DatetimeArray>
# ['2016-11-11 00:00:00', '2016-06-16 00:00:00', '2015-10-18 00:00:00',
#  '2014-06-14 00:00:00', '2017-04-20 00:00:00', '2016-12-10 00:00:00',
#  '2015-11-26 00:00:00', '2014-11-18 00:00:00', '2014-05-15 00:00:00',
#  '2014-09-01 00:00:00',
#  ...
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit'],
#       dtype='object')

# %%
df['Order ID'].unique()
# Out:
# array(['CA-2016-152156', 'CA-2016-138688', 'US-2015-108966', ...,
#        'CA-2014-110422', 'CA-2017-121258', 'CA-2017-119914'], dtype=object)

# %%
df['Order Date'].unique()
# Out:
# <DatetimeArray>
# ['2016-11-08 00:00:00', '2016-06-12 00:00:00', '2015-10-11 00:00:00',
#  '2014-06-09 00:00:00', '2017-04-15 00:00:00', '2016-12-05 00:00:00',
#  '2015-11-22 00:00:00', '2014-11-11 00:00:00', '2014-05-13 00:00:00',
#  '2014-08-27 00:00:00',
#  ...
#  '2016-10-11 00:00:00', '2014-06-18 00:00:00', '2017-02-28 00:00:00',
#  '2015-05-09 00:00:00', '2014-11-06 00:00:00', '2015-12-29 00:00:00',
#  '2014-04-03 00:00:00', '2016-06-03 00:00:00', '2015-04-12 00:00:00',
#  '2014-01-21 00:00:00']
# Length: 1237, dtype: datetime64[ns]

# %%
df['Ship Date'].unique()
# Out:
# <DatetimeArray>
# ['2016-11-11 00:00:00', '2016-06-16 00:00:00', '2015-10-18 00:00:00',
#  '2014-06-14 00:00:00', '2017-04-20 00:00:00', '2016-12-10 00:00:00',
#  '2015-11-26 00:00:00', '2014-11-18 00:00:00', '2014-05-15 00:00:00',
#  '2014-09-01 00:00:00',
#  ...
#  '2017-04-06 00:00:00', '2015-05-13 00:00:00', '2014-08-19 00:00:00',
#  '2017-01-20 00:00:00', '2015-03-28 00:00:00', '2016-08-25 00:00:00',
#  '2014-01-27 00:00:00', '2015-05-23 00:00:00', '2014-01-23 00:00:00',
#  '2017-03-03 00:00:00']
# Length: 1334, dtype: datetime64[ns]

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Customer Name'].unique()
# Out:
# array(['Claire Gute', 'Darrin Van Huff', "Sean O'Donnell",
#        'Brosina Hoffman', 'Andrew Allen', 'Irene Maddox', 'Harold Pawlan',
#        'Pete Kriz', 'Alejandro Grove', 'Zuschuss Donatelli', 'Ken Black',
#        'Sandra Flanagan', 'Emily Burns', 'Eric Hoffmann',
#        'Tracy Blumstein', 'Matt Abelman', 'Gene Hale', 'Steve Nguyen',
#        'Linda Cazamias', 'Ruben Ausman', 'Erin Smith', 'Odella Nelson',
#        "Patrick O'Donnell", 'Lena Hernandez', 'Darren Powers',
#        'Janet Molinari', 'Ted Butterfield', 'Kunst Miller',
#        'Paul Stevenson', 'Brendan Sweed', 'Karen Daniels',
#        'Henry MacAllister', 'Joel Eaton', 'Ken Brennan',
#        'Stewart Carmichael', 'Duane Noonan', 'Julie Creighton',
#        'Christopher Schild', 'Paul Gonzalez', 'Gary Mitchum', 'Jim Sink',
#        'Karl Braun', 'Roger Barcio', 'Parhena Norris', 'Katherine Ducich',
#        'Elpida Rittenbach', 'Rick Bensley', 'Gary Zandusky',
# ...

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Product ID'].unique()
# Out:
# array(['FUR-BO-10001798', 'FUR-CH-10000454', 'OFF-LA-10000240', ...,
#        'OFF-AP-10003099', 'TEC-PH-10002645', 'OFF-ST-10001627'],
#       dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Product Name'].unique()
# Out:
# array(['Bush Somerset Collection Bookcase',
#        'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#        'Self-Adhesive Address Labels for Typewriters by Universal', ...,
#        'Eureka Hand Vacuum, Bagless', 'LG G2',
#        'Eldon Jumbo ProFile Portable File Boxes Graphite/Black'],
#       dtype=object)

# %%
df['Sales'].unique()
# Out:
# array([261.96, 731.94,  14.62, ...,  97.98,  55.6 , 243.16])

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12], dtype=int8)

# %%
df['Discount'].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
df['Profit'].unique()
# Out:
# array([ 41.9136, 219.582 ,   6.8714, ...,   4.1028,  13.32  ,  72.948 ])

# %% [markdown]
# ### Missing Values

# %%
df.isna().sum()   # There is no missing values
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### Outlier

# %%
df3 = df.select_dtypes(exclude="object")
for i in df3.columns:
    Q1 = df3[i].quantile(0.25)
    Q3 = df3[i].quantile(0.75)

    IQR = Q3-Q1
    lower = Q1 - (1.5*IQR)
    upper = Q3 + (1.5*IQR)
    df3[(df3[i]<lower)] = lower
    df3[(df3[i]>upper)]= upper
    print(f"  {i} Lower_limit {lower} ")
    print(f"  {i} Upper_limit {upper} ")
    print()
# Out:
#   Order Date Lower_limit 2012-06-04 00:00:00
#   Order Date Upper_limit 2020-05-01 00:00:00
#
#   Ship Date Lower_limit 2012-06-08 00:00:00
#   Ship Date Upper_limit 2020-05-05 00:00:00
#
#   Sales Lower_limit -271.71000000000004
#   Sales Upper_limit 498.93
#
#   Quantity Lower_limit -4.0
#   Quantity Upper_limit 12.0
#
#   Discount Lower_limit -0.30000000000000004
#   Discount Upper_limit 0.5
#
#   Profit Lower_limit -26.014600000000012
#   Profit Upper_limit 44.69100000000002
# C:\Users\m\AppData\Local\Temp\ipykernel_2480\72365995.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '498.93' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df3[(df3[i]>upper)]= upper
# ...

# %% [markdown]
# ## Data Visualization
#
# ### Univariate Analysis

# %%
df['Profit'].plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Discount"].plot(kind = "hist",figsize = (3,2),title = "Histogram Of Discount")
# Out:
# <Axes: title={'center': 'Histogram Of Discount'}, ylabel='Frequency'>

# %%
df["Quantity"].plot(kind = "density",figsize = (3,2),title = "Density Plot Of Quantity")
# Out:
# <Axes: title={'center': 'Density Plot Of Quantity'}, ylabel='Density'>

# %%
df["Discount"].plot(kind = "density",figsize = (3,2),title = "Density Plot Of Discount")
# Out:
# <Axes: title={'center': 'Density Plot Of Discount'}, ylabel='Density'>

# %%
df['Sales'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Discount'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df["State"].value_counts().plot(kind = "barh",xlabel = "State",color = ["green","orange","red"],figsize=(20,10))
# Out:
# <Axes: xlabel='State', ylabel='State'>

# %%
sns.countplot(data = df,x = "Ship Mode")
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# ### Insights:-
#
# 1. In Category maximum Product Of Sales Purchased by the Office Supplies department.
# 2. California State purchased maximum number of product.
# 3. The maximum number of shipmode have been through standard class.

# %%
df['Region'].value_counts().plot(kind='pie',autopct = '%1.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sub-Category'].value_counts().plot(kind='pie',autopct = '%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Bi Varate Analysis
#
# ### Categoral - Categoral

# %%
pd.crosstab(df['Category'],df['State'])  #cat - cat
# Out:
# State            Alabama  Arizona  Arkansas  California  Colorado  \
# Category
# Furniture             11       49         9         444        51
# Office Supplies       36      127        36        1198        96
# Technology            14       48        15         359        35
#
# State            Connecticut  Delaware  District of Columbia  Florida  \
# Category
# Furniture                 13        18                     3       85
# Office Supplies           58        58                     6      229
# Technology                11        20                     1       69
#
# State            Georgia  ...  South Dakota  Tennessee  Texas  Utah  Vermont  \
# Category                  ...
# Furniture             32  ...             2         45    202     7        2
# Office Supplies      115  ...             8        118    604    39        6
# Technology            37  ...             2         20    179     7        3
#
# ...

# %%
sns.countplot(data = df, x = 'Sub-Category',hue='Country')
# Out:
# <Axes: xlabel='Sub-Category', ylabel='count'>

# %% [markdown]
# ### Categoral - Numerical

# %%
df.groupby('Category')['Sales'].max()
# Out:
# Category
# Furniture           4416.174
# Office Supplies     9892.740
# Technology         22638.480
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture           8.709119
# Office Supplies    20.327050
# Technology         78.752002
# Name: Profit, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   datetime64[ns]
#  2   Ship Date      9993 non-null   datetime64[ns]
#  3   Ship Mode      9993 non-null   object
#  4   Customer Name  9993 non-null   object
#  5   Segment        9993 non-null   object
#  6   Country        9993 non-null   object
#  7   City           9993 non-null   object
#  8   State          9993 non-null   object
#  9   Region         9993 non-null   object
#  10  Product ID     9993 non-null   object
#  11  Category       9993 non-null   object
#  12  Sub-Category   9993 non-null   object
#  13  Product Name   9993 non-null   object
#  14  Sales          9993 non-null   float64
#  15  Quantity       9993 non-null   int8
#  16  Discount       9993 non-null   float64
# ...

# %%
df['Sales'].plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# ### Numerical - Numerical

# %%
df.corr(numeric_only= True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200808 -0.028197  0.479067
# Quantity  0.200808  1.000000  0.008680  0.066241
# Discount -0.028197  0.008680  1.000000 -0.219481
# Profit    0.479067  0.066241 -0.219481  1.000000

# %%
df.plot('Sales','Quantity',kind = 'scatter')
# Out:
# <Axes: xlabel='Sales', ylabel='Quantity'>

# %%
df.plot('Sales','Profit',kind = 'scatter')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# ### Multivaraite Analysis

# %%
df.corr(numeric_only=True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200808 -0.028197  0.479067
# Quantity  0.200808  1.000000  0.008680  0.066241
# Discount -0.028197  0.008680  1.000000 -0.219481
# Profit    0.479067  0.066241 -0.219481  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
